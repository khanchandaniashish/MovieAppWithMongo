# %%
import json

# %%
import ijson

file_path = '/Users/ashish/Documents/Semester 2/NoSQL/Team Project/dataset/output.json'

def validate_large_json_file(file_path):
    with open(file_path, 'rb') as f:
        parser = ijson.parse(f)
        for prefix, event, value in parser:
            pass
    print("The JSON file is valid.")

validate_large_json_file(file_path)
# Out:
# The JSON file is valid.

# %%
file_path = '/Users/ashish/Documents/Semester 2/NoSQL/Team Project/dataset/metadata.json'
validate_large_json_file(file_path)
# Out:
# The JSON file is valid.

# %%
import pandas as pd

reviews = '/Users/ashish/Documents/Semester 2/NoSQL/Team Project/dataset/output.json'
movies = '/Users/ashish/Documents/Semester 2/NoSQL/Team Project/dataset/metadata.json'

df1 = pd.read_json('/Users/ashish/Documents/Semester 2/NoSQL/Team Project/dataset/metadata.json')
df2 = pd.read_json(reviews)

# %%
merged_df = pd.merge(df1, df2, on='item_id', how='outer')

# %%
merged_df.to_json('merged_file_withid.json', orient='records', lines=True)

# %%
merged_df.iloc[0:10]
# Out:
#               title     directedBy  \
# 0  Toy Story (1995)  John Lasseter
# 1  Toy Story (1995)  John Lasseter
# 2  Toy Story (1995)  John Lasseter
# 3  Toy Story (1995)  John Lasseter
# 4  Toy Story (1995)  John Lasseter
# 5  Toy Story (1995)  John Lasseter
# 6  Toy Story (1995)  John Lasseter
# 7  Toy Story (1995)  John Lasseter
# 8  Toy Story (1995)  John Lasseter
# 9  Toy Story (1995)  John Lasseter
#
#                                             starring dateAdded  avgRating  \
# 0  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...      None    3.89146
# 1  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...      None    3.89146
# 2  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...      None    3.89146
# 3  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...      None    3.89146
# 4  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...      None    3.89146
# 5  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...      None    3.89146
# ...

# %%
grouped_df = merged_df.groupby('item_id')

# %%
pruned_df = grouped_df.apply(lambda x: x.head(25))

# %%
pruned_df = pruned_df.drop('item_id', axis=1).reset_index(drop=True)

# %%
pruned_df.iloc[0:27]
# Out:
#                title     directedBy  \
# 0   Toy Story (1995)  John Lasseter
# 1   Toy Story (1995)  John Lasseter
# 2   Toy Story (1995)  John Lasseter
# 3   Toy Story (1995)  John Lasseter
# 4   Toy Story (1995)  John Lasseter
# 5   Toy Story (1995)  John Lasseter
# 6   Toy Story (1995)  John Lasseter
# 7   Toy Story (1995)  John Lasseter
# 8   Toy Story (1995)  John Lasseter
# 9   Toy Story (1995)  John Lasseter
# 10  Toy Story (1995)  John Lasseter
# 11  Toy Story (1995)  John Lasseter
# 12  Toy Story (1995)  John Lasseter
# 13  Toy Story (1995)  John Lasseter
# 14  Toy Story (1995)  John Lasseter
# 15  Toy Story (1995)  John Lasseter
# 16  Toy Story (1995)  John Lasseter
# 17  Toy Story (1995)  John Lasseter
# 18  Toy Story (1995)  John Lasseter
# 19  Toy Story (1995)  John Lasseter
# 20  Toy Story (1995)  John Lasseter
# 21  Toy Story (1995)  John Lasseter
# 22  Toy Story (1995)  John Lasseter
# 23  Toy Story (1995)  John Lasseter
# 24  Toy Story (1995)  John Lasseter
# ...

# %%
pruned_df.to_json('pruned_file_withId_25.json', orient='records', lines=True) # this came to 250mb

# %%
pruned_df.shape
# Out:
# (767000, 7)

# %%
pruned_df['title'].nunique()
# Out:
# 84484
